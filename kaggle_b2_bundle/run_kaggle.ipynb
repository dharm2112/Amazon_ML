# %% [markdown]
# # TriMatch-ER B2 — Kaggle Pipeline Execution Notebook
# Run this notebook on Kaggle GPU (T4 / P100 / L4).
#
# ### Step 1: Install Dependencies & Copy Script

# %%
# !pip install -q rapidfuzz sentence-transformers lightgbm joblib tqdm
import glob, os, shutil
# Find generate_submission_b2_kaggle.py anywhere under /kaggle/input and copy to working dir
scripts = glob.glob('/kaggle/input/**/generate_submission_b2_kaggle.py', recursive=True)
if scripts:
    shutil.copy(scripts[0], './generate_submission_b2_kaggle.py')
    print(f'Copied {scripts[0]} to current working directory.')

# %% [markdown]
# ### Step 2: Run Full Pipeline
# Auto-detects model weights, candidates, and test TSVs from Kaggle Dataset input files.

# %%
# !python generate_submission_b2_kaggle.py --mode full

# %% [markdown]
# ### Step 3: Check Output Submission Zip
# Outputs `submission_b2.zip` in `/kaggle/working/submission_b2.zip`.

# %%
# !ls -lh /kaggle/working/submission_b2.zip
